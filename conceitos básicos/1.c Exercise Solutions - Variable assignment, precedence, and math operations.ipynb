# %% [markdown]
# # <font color='red'> *ABSOLUTE BEGINNER LEVEL* </font>
# ## <font color='red'> VARIABLES, DATATYPES, MATHEMATICAL OPERATIONS, PRECEDENCE AND VARIABLE ASSIGNMENT </font>

# %% [markdown]
# #  <font color='blue'>1. WHAT WILL THIS CODE GENERATE?  </font>

# %%
x = 10
x = 20
x = 15
x
# Out:
# 15

# %%
type(x)
# Out:
# int

# %%
z = x/y
z
# Out:
# 7.5

# %%
type(z)
# Out:
# float

# %% [markdown]
# #  <font color='blue'>2. WRITE A CODE THAT CALCULATES THE AREA AND PERIMETER OF A RECTANGE (ASSUME ANY VALUES FOR LENGTH AND WIDTH) </font>
# ![image.png](attachment:image.png)

# %%
a = 2
b = 3
area = a*b
per = 2 * (a+b)

# %%
area
# Out:
# 6

# %%
per
# Out:
# 10

# %% [markdown]
# #  <font color='blue'> 3. WHAT WILL THIS CODE GENERATE? </font>

# %%
x = 25
y = 20
z = 3
f = 2

# %%
ans = (x - y) * z / f       
print ("Result =", ans)
# Out:
# Result = 7.5

# %%
e = ((x - y) * z) / f    
print("Result =",  ans)
# Out:
# Result = 7.5

# %%
e = (x - y) * (z / f);    
print("Result =",  ans)
# Out:
# Result = 7.5

# %% [markdown]
# # <font color='blue'> 4. WRITE TO CODE TO TEST IF A NUMBER IS EVEN OR ODD </font>

# %%
x = 20 
y = x%2 
y
# Out:
# 0

# %% [markdown]
# # <font color='blue'> 5. WRITE A CODE THAT TAKES A NUMBER, SQUARE IT AND THEN TAKE THE RESULT AND GET THE SQUARE ROOT (SO YOU END UP WITH THE ORIGINAL VALUE!) </font>

# %%
x = 4
y = x**2
y
# Out:
# 16

# %%
import math 
z = math.sqrt(y)
z
# Out:
# 4.0

# %% [markdown]
# # <font color='blue'> 6. WRITE A CODE THAT TAKES A DIMENSION OF A CUBE AND OBTAIN ITS AREA AND VOLUME </font>
# ![image.png](attachment:image.png)

# %%
a = 20 
area = 6 * a * a
volume = a * a * a

# %%
area
# Out:
# 2400

# %%
volume
# Out:
# 8000

# %% [markdown]
# # <font color='blue'> 7. WRITE A CODE THAT TAKES A NUMBER AND INCREMENTS IT 3 TIMES </font>

# %%
x = 40
x+=3
x
# Out:
# 43

# %%
x = 40
x+=1
x+=1
x+=1
x
# Out:
# 43

# %% [markdown]
# #  <font color='blue'>8. WHAT WENT WRONG? ADD LINES OF CODE SO THAT Z BECOMES EQUAL 55 </font>

# %%
x = 20
y = 30

z = x + y + s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-738ec72f01b1> in <module>()
#       2 y = 30
#       3
# ----> 4 z = x + y + s
#
# NameError: name 's' is not defined

# %% [markdown]
# #  <font color='blue'>9. WRITE A CODE THAT PERFORMS THE FOLLOWING MATHEMATICAL OPERATION </font>
# z = |x − y| *  (x + y)

# %%
x = 4
y = 2
z = abs(x-y) * (x+y)

# %%
z
# Out:
# 12

# %% [markdown]
# #  <font color='blue'> 10. WHICH ONE OF THE FOLLOWING SHOULD BE ELIMINATED TO EXECUTE THE CODE SUCCESSFULLY?
# - Comment the line(s) that causes the error
# - AND remove the variable from the print command   </font>

# %% [markdown]
# # Variable naming rules
# - Variables names must start with a letter or an underscore, such as:
#     - _salary
#     - salary_
# - The remainder of your variable name may consist of letters, numbers and underscores.
#     - salary1
#     - salary2018x
#     - speed_kph
# - Names are case sensitive.
#     - salary, SALARY represents different variables.
#
# - Don't start variable name with a number
# - List of reserved words are listed below
#
#     ![image.png](attachment:image.png)

# %%
salary = 20 # dollars per hour
Salary = 25
for = 10
saLary = 12
SALARY = 13
s_a_l_a_r_y = 15
2SALARY = 30
_salary = 30
True = 20
salary_ = 33
_SALARY_ = 36

print(salary, Salary, for, saLary, SALARY, s_a_l_a_r_y, 2SALARY, _salary, True, salary_, _SALARY_)

# %% [markdown]
# #  <font color='blue'> 11. WRITE A CODE THAT TAKES CELSIUS TEMPERATURE AND CONVERT IT TO FAHRENHEIT  </font>
# ![image.png](attachment:image.png)
# # F = 9/5*C+32

# %%
Celsius = 23
Fahrenheit = 9.0/5.0 * Celsius + 32
Fahrenheit
# Out:
# 73.4

# %% [markdown]
# # <font color='blue'> 12. WRITE A CODE THAT CONVERTS FROM KM/H INTO MILES PER HOUR (REFER TO THE EQUATION BELOW)  </font>
# ![image.png](attachment:image.png)

# %%
kmh = 90
mph =  0.6214 * kmh
mph
# Out:
# 55.925999999999995

# %% [markdown]
# # NOW YOU SHOULD BE FAMILIAR WITH VARIABLES, VARIABLE ASSIGNMENTS, PRECEDENCE AND BASIC MATHEMATICAL OPERATIONS, GREAT JOB!
