# %% [markdown]
# # FUNDAMENTOS DA PROGRAMAÇÃO EM PYTHON

# %% [markdown]
# Esse notebook vai cobrir os seguintes tópicos:
# - Operadores de Comparação
# - Operadores Lógicos
# - Conditional statements (If-else)

# %% [markdown]
# # Operadores de Comparação
# ![image.png](attachment:image.png)
#
# Reference: https://www.tutorialspoint.com/python/python_basic_operators.htm

# %%
15 > 8
# Out:
# True

# %%
5 >=5
# Out:
# True

# %%
5 ==5
# Out:
# True

# %%
5 ==6
# Out:
# False

# %%
x = 6

# %%
x
# Out:
# 6

# %%
'Hello' == 'Hello'
# Out:
# True

# %%
'Hello' == 'HELLO'
# Out:
# False

# %%
6 != 5
# Out:
# True

# %%
5 !=5
# Out:
# False

# %%
15>6 # True
# Out:
# True

# %%
15!=6 #True
# Out:
# True

# %%
15==6 #False
# Out:
# False

# %%
15<=6 # False
# Out:
# False

# %% [markdown]
# # OPERADORES LÓGICOS

# %%
True and False # 1 and 0 = 0
# Out:
# False

# %%
True and True # 1 and 1 = 1
# Out:
# True

# %%
False and True # 0 and 1 = 0
# Out:
# False

# %%
False and False # 0 and 0 = 0
# Out:
# False

# %%
True or True # 1 or 1 = 1
# Out:
# True

# %%
True or False # 1 or 0 = 1
# Out:
# True

# %%
False or True # 0 or 1 = 1
# Out:
# True

# %%
False or False # 0 or 0 = 0
# Out:
# False

# %%
(6>2) and (2==5) # True and False = False
# Out:
# False

# %%
(6>2) or (2==5) # True or False = True
# Out:
# True

# %%
(2==3) and (4==3) and (10==10) # False and False and True = False
# Out:
# False

# %% [markdown]
# # CONDITIONAL STATEMENTS

# %%
if 5 > 2:
    print('True')
else:
    print('False')
# Out:
# True

# %%
if 5 > 2:
    print('If condition is True')
else:
    print('If condition is False')
# Out:
# If condition is True

# %%
if 5 == 10:
    print('If condition is True')
else:
    print('If condition is False')
# Out:
# If condition is False

# %%
if 5 ==7:
    print('First statement is true')
elif 2 == 4:
    print('Second statement is true')
else:
    print('Last statement is true')
# Out:
# Last statement is true

# %%
if 5 <7:
    print('First statement is true')
elif 2 >4:
    print('Second statement is true')
else:
    print('Last statement is true')
# Out:
# First statement is true

# %%
name = input('Enter your username:')

if name == 'Ryan':
    print("Access granted")
else:
    print("Access Denied")
# Out:
# Enter your username:RYAN
# Access Denied

# %%
name = input('Enter your username:')

if name == 'Ryan' or name =='RYAN' or name =='ryan':
    print("Access granted")
else:
    print("Access Denied")
# Out:
# Enter your username:Ryan1
# Access Denied
